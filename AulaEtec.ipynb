# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonalffa/Ciencia-de-dados/blob/main/AulaEtec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Utilizando a IA
# Out:
#   File "/tmp/ipykernel_2703/1244232454.py", line 1
#     Utilizando a IA
#                ^
# SyntaxError: invalid syntax

# %%
from google.colab import ai
response = ai.generate_text(input())
print(response)
# Out:
# Ola Mundo
# Olá! Tudo bem?
#
# "Olá Mundo" é um ótimo começo! 😊
